# %% [markdown]
# ## Massachusetts RPS / PTS
#
# The Commonwealth of Massachusetts provides data on all of the renewable energy generation facilites, including both commercial and residential, through its website [Lists of Qualified Generation Units](https://www.mass.gov/service-details/lists-of-qualified-generation-units) and directs the user to 7 different programs, see list below.
#
# * [RPS 1](https://www.mass.gov/doc/eligible-class-i-renewable-generation-units-0)
# * [SREC I](https://www.mass.gov/files/documents/2017/10/27/Solar%20Carve-Out%20Qualified%20Units%20080717_0.xlsx)
# * [SREC II](https://www.mass.gov/doc/solar-carve-out-ii-qualified-renewable-generation-units)
# * [SMART](https://www.mass.gov/doc/smart-qualified-units-list)
# * [CLASS 2](https://www.mass.gov/doc/rps-class-ii-qualified-units-list-2/download)
# * [WASTE](https://www.mass.gov/files/documents/2017/10/27/eligible-class2-waste-units.xls)
# * [APS](https://www.mass.gov/doc/aps-qualified-units-list-6)
#
# Verification of monthly production data is centralized through the Massachusetts Clean Energy Center - [Production Tracking System](https://www.masscec.com/about-pts).  PTS data is lagged and currently (Nov21) through March, 2021.  The overlap with the individual *Lists of Qualified Generation Units* is high but with differing data items; see detail and a column naming normalization below.  The [monthly production data](http://files.masscec.com/innovate-clean-energy/prod-track-system/PTSSRECCapacityReport.xlsx) for a large fraction of all systems is available for the years 2010 - 2016 and shows an average 13.71% "capacity"; the proportion of stated kW capacity actually produced.
#
# ### Issues
#
# * no unique key
# * no (lat,lon) coordinates / location indeterminate

# %%
import pandas as pd
import numpy  as np

import matplotlib.pyplot as plt
import matplotlib.ticker as mtick  ##format charts for dollars ($) 

from datetime import datetime, timedelta
import locale  ##format currency for display

locale . setlocale ( locale.LC_ALL , 'en_US.UTF-8' )
# Out:
# 'en_US.UTF-8'

# %%
## Monthly production data from 2010 - 2016 by installation; no key to PTS data
def get_monthly_production_data_2010_2016 ( ) :
    file  =  'http://files.masscec.com/innovate-clean-energy/prod-track-system/PTSSRECCapacityReport.xlsx'

    raw   =  pd . read_excel ( file , sheet_name = 2 )
    raw   =  raw .iloc [ 5 : , : ] #[ spec [ 'skip_rows' ] : , spec [ 'skip_columns' ] : ]
    raw . columns = [ 'year' , 'kW' , 'Jan' , 'Feb' , 'Mar' , 'Apr' , 'May' , 'Jun' , 'Jul' , 'Aug' , 'Sep' , 'Oct' , 'Nov' , 'Dec' , 'total'  , 'cf' ]
    return raw

production_data = get_monthly_production_data_2010_2016 ( )

production_data . groupby ( 'year' ) . agg ( { "cf" : [ np . mean , len ] } )
# Out:
#             cf
#           mean    len
# year
# 2010  0.131844   1175
# 2011  0.127483   1640
# 2012  0.134607   3035
# 2013  0.132894   6177
# 2014  0.130688  10504
# 2015  0.131204  11137
# 2016  0.135889  12751

# %%
norms = {
    'http://files.masscec.com/uploads/attachments/PVinPTSwebsite.xlsx' : {
        'short_name' :  'pts' ,
        'skip_rows'  :  8 ,
        'skip_columns' :   0 ,
        'columns'    :  ['kW','effective_date','cost','grant','city','zip','county','program','type','installer',
                         'module_mfgr','inverter_mfgr','meter_mfgr','utility','owner','srec','est_annual_kWh']
    },
    '/data/energy/REC/MA/Solar Carve-Out Qualified Units 080717_0.xlsx' : {
        'short_name' : 'srec1' ,
        'skip_rows'  :  6 ,
        'skip_columns' : 1 ,
        'columns'    : ['rps_id','nepool_id','aggregation','applicant','name','type','city','zip','kW',
                        'effective_date','operation_date','sq_date','utility','installer','cost','perWatt']
    },
    '/data/energy/REC/MA/RPS_Solar_Carve-out_II_Renewable_Generation_Units_2021-09-01.xlsx' : {
        'short_name' : 'srec2' ,
        'skip_rows'  : 12 ,
        'skip_columns' :   0 ,
        'columns'    : ['rps_id','nepool_id','applicant','name','type','city','zip','kW','sector','subsector',
                        'srec_factor','effective_date','operation_date','qualification_date','distributer','installer',
                        'cost','perWatt']
    },
    '/data/energy/REC/MA/SMART_Solar_Tariff_Generation_Units.xlsx' : {
        'short_name' : 'smart' ,
        'skip_rows'  :  20 ,
        'skip_columns' : 0 ,
        'columns'    : ['project','status','capacity_block','expiration_date','operation_date','effective_date',
                        'distributor','applicant','installer','owner','ownership_type',
                        'type','city','zip','size','kW_ac','kW',
                        'location','location_tranche','off_taker','off_taker_tranche','tracking','tracking_tranche',
                        'pollinator','pollinator_tranche','storage','storage_tranche','storage_kVa','storage_duration',
                        'low_income','land_use','interconnection','meter_type','standalone','cost','perWatt']
    },    
    '/data/energy/REC/MA/RPS_Class_0I_Renewable_Generation_Units.xlsx' : {
        'short_name' : 'rps1' ,
        'skip_rows'  :  16 ,
        'skip_columns' :   0 ,
        'columns'    : ['type','rps_id','nepool_id','name','city','state','fuel','MW','output_percent','aggregator',
                        'verifier','effective_date','qualification_date']
    },
    '/data/energy/REC/MA/Eligible-Class2-Units_20210921.xlsx' : {
        'short_name'   : 'class2' ,
        'skip_rows'    :  17 ,
        'skip_columns' :   1 ,
        'columns'      : ['rps_id','nepool_id','name','city','state','fuel','MW','output_percent',
                        'verifier','effective_date','sq_date']
    },
    '/data/energy/REC/MA/eligible-class2-waste-units.xlsx' : {
        'short_name'   : 'waste' ,
        'skip_rows'    :  2 ,
        'skip_columns' :   1 ,
        'columns'      : ['rps_id','nepool_id','name','city','state','fuel','MW','sq_date','effective_date','output_percent']
    },
    '/data/energy/REC/MA/APS_QUL_1-13-21.xlsx' : {
        'short_name'   : 'aps' ,
        'skip_rows'    :  2 ,
        'skip_columns' :  1 ,
        'columns'    : ['rps_id','nepool_id','name','city','state','fuel','MW','effective_date','operation_date',
                        'rep','verifier']
    },
    
}

# %%
mask = pts.city=='Arlington'
print('PTS,{installs},{first},{last}'.format(installs=len(pts[mask]),first=pts[mask].effective_date.min(),last=pts[mask].effective_date.max()))

mask = rps.city=='Arlington'
print('RPS,{installs},{first},{last}'.format(installs=len(rps[mask]),first=rps[mask].effective_date.min(),last=rps[mask].effective_date.max()))
# Out:
# PTS,947,2003-08-18 00:00:00,2021-03-09 00:00:00
# RPS,1060,2010-07-22 00:00:00,2021-08-27 00:00:00

# %%
mask = pts.effective_date<='2018-12-31'
print('PTS,{installs},{first},{last}'.format(installs=len(pts[mask]),first=pts[mask].effective_date.min(),last=pts[mask].effective_date.max()))

mask = rps.effective_date<='2018-12-31'
print('RPS,{installs},{first},{last}'.format(installs=len(rps[mask]),first=rps[mask].effective_date.min(),last=rps[mask].effective_date.max()))
# Out:
# PTS,90835,2002-12-17 00:00:00,2018-12-31 00:00:00
# RPS,87617,2010-01-01 00:00:00,2018-12-31 00:00:00

# %%
def extract_massgov_rps ( file , spec ):
    
    raw  =  pd . read_excel ( file )

    rps  =  raw .iloc [ spec [ 'skip_rows' ] : , spec [ 'skip_columns' ] : ]


    ## assign column names, change the defaults to normalize across datasets
    ### cols =  raw . iloc [ skip_rows - 1 , : ] . tolist ( )
    rps . columns  =  spec [ 'columns' ]

    ## reset index after dropped rows
    rps  =  rps . reset_index ( drop = True )
    
    ## make effective date a pandas datetime index
    mask = rps [ 'effective_date' ] . astype ( str ) . str . contains ( 'Pending|Not Operational' )
    rps . loc [ mask , 'effective_date' ]  =  np.nan
    rps [ 'effective_date' ]  =  pd . to_datetime ( rps [ 'effective_date' ] )

    for col in [ 'kW' , 'cost' , 'est_annual_kWh' ] :
        if col in spec [ 'columns' ] :
            rps [ col ] =  rps [ col ] . astype ( np . float64 )
            
    ## MW to floats
    if 'MW' in spec [ 'columns' ] :
        
        if spec [ 'short_name' ] == 'rps1' :
            mask = rps . MW . str . contains ( 'capacity' ) == True
            rps .loc  [ mask, 'MW' ] = '0'
        elif spec [ 'short_name' ] == 'aps' :
            mask = rps . MW . str . contains ( ' thermal ') == True
            rps . loc [ mask , 'MW' ] = 0

        rps . MW = rps . MW . astype ( np . float64 ) 

    if 'state' in spec [ 'columns' ] :
        rps. loc [ : , 'state'] = rps . state . str . upper ( ) . str . replace ( ' ' , '' )        

    return rps

# %%
docs = {}
for file in norms . keys ( ) :   
    docs [ norms [ file ] [ 'short_name' ] ]  = extract_massgov_rps ( file , norms [ file ] )

## 2 installs before 2003, outliers
docs [ 'pts' ] = docs [ 'pts' ] [ docs [ 'pts' ] . effective_date >= '2002-12-17' ]

## remove footers
docs [ 'class2' ]  =  docs [ 'class2' ] . iloc [ : -7 , : ]
docs [ 'rps1'   ]  =  docs [ 'rps1'   ] . iloc [ : -5 , : ]
docs [ 'aps'    ]  =  docs [ 'aps'    ] . iloc [ : -6 , : ]
docs [ 'waste'  ]  =  docs [ 'waste'  ] . iloc [ : -2 , : ]

# %% [markdown]
# ## merge PTS and rps (RPS1, RPS2, SMART)

# %%
docs['smart']['rps_id'] = docs['smart']['project']

rps = docs['smart'].append(docs['srec1']).append(docs['srec2'])
rps = rps.reset_index(drop=True)

# %%
## Compare number of rows in PTS to the sum of the three PV programs; 
## RPS1, RPS2 and the current SMART solar programs 
## taking into consideration the reporting lag in the PTS system

summary  =  pd . DataFrame ( )

for  program  in  docs . keys ( ) :
    if 'kW' in docs [ program ] . columns :
        summary  =  summary . append ( {
            'program' : program ,
            'systems' : len ( docs [ program ] ) ,
            'MW'      : docs [ program ] . kW . sum ( ) / 1000 ,
            'start'   : docs [ program ] [ 'effective_date' ] . min ( ) . strftime ( '%Y-%m-%d' ) ,
            'last'    : docs [ program ] [ 'effective_date' ] . max ( ) . strftime( '%Y-%m-%d' )
        } , ignore_index = True )
    else :
        summary  =  summary . append ( {
            'program' : program ,
            'systems' : len ( docs [ program ] ) ,
            'MW'      : docs [ program ] . MW . sum ( )  ,
            'start'   : docs [ program ] [ 'effective_date' ] . min ( ) . strftime ( '%Y-%m-%d' ) ,
            'last'    : docs [ program ] [ 'effective_date' ] . max ( ) . strftime( '%Y-%m-%d' )
        } , ignore_index = True )

summary [ 'systems' ]  =  summary [ 'systems' ] . astype ( int )

print(summary.to_markdown())


mask = docs [ 'smart' ] . effective_date <= summary . loc [ summary . program == 'pts' , 'last' ] . values [ 0 ]

diff = summary . loc [ summary . program == 'pts' , 'systems' ] . values [ 0 ] - \
                      (len ( docs [ 'smart' ] [ mask ] ) + \
                         summary . loc [ summary . program == 'srec1' , 'systems' ] . values [ 0 ] + \
                         summary . loc [ summary . program == 'srec2' , 'systems' ] . values [ 0 ]
                      )

MW = round ( docs [ 'smart' ] [ mask ] . kW . sum ( ) / 1000 , 1 )

print ('\n\n' ,
       diff ,
       'more PTS installs compared to the combined SREC1 + SREC2 + SMART programs reducing SMART MW by' , 
       MW
      )
# Out:
# |    | program   |   systems |       MW | start      | last       |
# |---:|:----------|----------:|---------:|:-----------|:-----------|
# |  0 | pts       |    114552 | 2961.03  | 2002-12-17 | 2021-04-06 |
# |  1 | srec1     |     11795 |  653.329 | 2010-01-01 | 2013-12-31 |
# |  2 | srec2     |     75869 | 1753.68  | 2013-07-23 | 2020-10-01 |
# |  3 | smart     |     45325 | 2169     | 2018-06-18 | 2021-12-16 |
# |  4 | rps1      |      9261 | 6753.5   | 2002-01-01 | 2021-07-01 |
# |  5 | class2    |       162 |  394.039 | 2009-01-01 | 2021-01-01 |
# |  6 | waste     |         7 |  283.545 | 2009-01-01 | 2009-01-01 |
# |  7 | aps       |       125 |  515.832 | 2009-04-01 | 2020-03-31 |
#
#
#  261 more PTS installs compared to the combined SREC1 + SREC2 + SMART programs reducing SMART MW by 664.6

# %% [markdown]
# |    | program   |   systems |       MW | start      | last       |
# |---:|:----------|----------:|---------:|:-----------|:-----------|
# |  0 | pts       |    114552 | 2961.03  | 2002-12-17 | 2021-04-06 |
# |  1 | srec1     |     11795 |  653.329 | 2010-01-01 | 2013-12-31 |
# |  2 | srec2     |     75869 | 1753.68  | 2013-07-23 | 2020-10-01 |
# |  3 | smart     |     45325 | 2169     | 2018-06-18 | 2021-12-16 |
# |  4 | rps1      |      9261 | 6753.5   | 2002-01-01 | 2021-07-01 |
# |  5 | class2    |       162 |  394.039 | 2009-01-01 | 2021-01-01 |
# |  6 | waste     |         7 |  283.545 | 2009-01-01 | 2009-01-01 |
# |  7 | aps       |       125 |  515.832 | 2009-04-01 | 2020-03-31 |

# %%
def exceptions(pts):

    total_installations   = len ( pts . kW )
    total_kW_installed    = pts . kW . sum ( )

    ##150 zero cost thru 4/2021 about 2.2% of total kW installed
    zero_cost = pts [ pts.cost == 0 ] . kW . sum ( )

    ##100 have no install dates, less than .03% of kW installed
    no_install_date = pts [ pd.isnull(pts.effective_date) ] . kW . sum ( )

    ##432 have costs per Watt much too high, 0.15% of kW installed
    high_Per_Watt = pts [ pts.perWatt > 10 ] . kW . sum ( )

    #      "{no_num} show no install date totaling {no_install_date}MW comprising {no_percent}% of total Watt capacity\n"
    print (
        ( "Exceptions in PTS dataset:\n\n" +\
          "{zc_num} show no cost         totaling {zero_cost}MW comprising {zc_percent}% of total Watt capacity\n"
          "{hi_num} show Per Watt > $10  totaling {high_Per_Watt}MW comprising {hi_percent}% of total Watt capacity\n"
        ) \
        . format (
            total_installations  =  total_installations,
            zc_num               =  len ( pts [ pts.cost == 0 ] ) ,
            zero_cost            =  round ( zero_cost / 1000 , 1 ) ,
            zc_percent           =  round ( 100 * zero_cost / total_kW_installed , 1 ) ,
    #         no_num               =  len ( pts [ pd.isnull(pts.effective_date) ] ) ,
    #         no_install_date      =  round ( no_install_date / 1000 , 1 ) ,
    #         no_percent           =  round ( 100 * no_install_date / total_kW_installed , 1 ) ,
            hi_num               =  len ( pts [ pts.perWatt > 10 ] ) ,
            high_Per_Watt        =  round ( high_Per_Watt / 1000 , 1 ) ,
            hi_percent           =  round ( 100 * high_Per_Watt / total_kW_installed , 1 ) ,
        )
    )

# %%
pts = docs [ 'pts' ] . copy ( )
pts [ 'perWatt' ] = pts . cost . div ( pts . kW ) / 1000

NM_RATE  = 0.215
RATE     = 0.11
url = 'http://files.masscec.com/uploads/attachments/PVinPTSwebsite.xlsx'

mask = pts [ 'type' ] . str . contains ( 'Residential' )

#     "and net metered rebates of {nmreturning}M (assuming a constant {nm_rate} rate)**.\n\n" +\
#     "with an estimated annual retail (net metered) value of {est_annual_value}M ({est_annual_nmval}M)."
print (
    ("PTS dataset: {url}\n\n" +\
     "There are {count} PV systems ({Rcount} residential) in Massachusetts\n" +\
     "installed between {min_date} and {max_date}\n"  +\
     "by {vendors} unique vendors (22 vendors account for 85% of all installs).\n\n" +\
     "A total of {kW}MW capacity has been installed of which {kW_res}MW is residential\n"    +\
     "at a cost of {invested}M\n" +\
     "generating an estimated {generated}TWh of electricity over the past {years} years\n" +\
     "with  a retail  value of {returning}M (assuming a constant {rate} rate)\n\n" +\
     "Expected energy output from all PV installations is {est_annual}TWh per year\n" +\
     "with an estimated annual retail value of {est_annual_value}M.\n\n"
    ) \
       . format (
    url      =  url ,
    count    =  len ( pts ) ,
    Rcount   =  len ( pts [ mask ] ) ,
    vendors  =  len ( pts . installer . unique ( ) ),
    kW       =  int ( round ( pts . kW . sum ( ) / 1000 , 0 ) ) ,   ## convert kW to MW
    kW_res   =  int ( round ( pts [ mask ] . kW . sum ( ) / 1000 , 0 ) ) ,   ## convert kW to MW
    invested =  locale . currency ( pts . cost . sum ( ) / 1e6 , grouping = True ) , ##convert to millions of $s
    generated = round ( ( ( ( datetime . today ( ) - pts . effective_date ) / timedelta ( days = 365 ) ) * pts.est_annual_kWh ) . sum ( ) / 1e9 , 2 ) , 
    returning   = locale . currency ( RATE * ( ( ( datetime . today ( ) - pts . effective_date ) / timedelta ( days = 365 ) ) * pts . est_annual_kWh ) . sum ( ) / 1e6 , grouping = True ), 
    nmreturning = locale . currency ( NM_RATE * ( ( ( datetime . today ( ) - pts [ mask ] . effective_date ) / timedelta ( days = 365 ) ) * pts [ mask ] . est_annual_kWh ) . sum ( ) / 1e6 , grouping = True ), 
    years = round ( ( pts . effective_date . max ( ) - pts . effective_date . min ( ) ) / timedelta ( days = 365 ) , 1 ) ,
    min_date =  pts . effective_date . min ( ) . strftime( "%Y-%m-%d" ) ,
    max_date =  pts . effective_date . max ( ) . strftime( "%Y-%m-%d" ) ,
    est_annual = round ( ( pts . est_annual_kWh ) . sum ( ) / 1e9 , 2 ) ,
    est_annual_value = locale . currency ( RATE * ( ( pts . est_annual_kWh ) . sum ( ) ) / 1e6 ) ,  ##in millions of $s
    est_annual_nmval = locale . currency ( NM_RATE * ( ( pts [ mask ] . est_annual_kWh ) . sum ( ) ) / 1e6 ) ,  ##in millions of $s
    rate = locale . currency ( RATE ),
    nm_rate = locale . currency ( NM_RATE )
) )

exceptions(pts)
# Out:
# PTS dataset: http://files.masscec.com/uploads/attachments/PVinPTSwebsite.xlsx
#
# There are 114552 PV systems (107441 residential) in Massachusetts
# installed between 2002-12-17 and 2021-04-06
# by 991 unique vendors (22 vendors account for 85% of all installs).
#
# A total of 2961MW capacity has been installed of which 803MW is residential
# at a cost of $8,902.49M
# generating an estimated 18.83TWh of electricity over the past 18.3 years
# with  a retail  value of $2,070.79M (assuming a constant $0.11 rate)
#
# Expected energy output from all PV installations is 3.62TWh per year
# with an estimated annual retail value of $398.10M.
#
#
# Exceptions in PTS dataset:
#
# 150 show no cost         totaling 65.4MW comprising 2.2% of total Watt capacity
# 427 show Per Watt > $10  totaling 4.7MW comprising 0.2% of total Watt capacity

# %%
mask = (pts.city=='Arlington') & (pts.effective_date<='20181231') & (pts.kW>10)
pts[mask].sort_values('kW')
# Out:
#             kW effective_date        cost     grant       city   zip  \
# 68465    10.14     2016-02-01    56784.00         0  Arlington  2474
# 28984    10.15     2018-07-17    30450.00         0  Arlington  2474
# 54112    10.34     2016-08-31    37958.80         0  Arlington  2474
# 52522    10.40     2016-10-03    51168.00         0  Arlington  2474
# 98735    10.46     2014-07-03    55736.00      2000  Arlington  2476
# 92348    10.46     2015-01-05    57502.50         0  Arlington  2474
# 73351    10.50     2015-12-04    49199.00         0  Arlington  2474
# 27023    10.56     2018-09-14    20267.00         0  Arlington  2474
# 73370    10.79     2015-12-04    48478.20         0  Arlington  2474
# 34616    10.85     2018-01-24    37975.00         0  Arlington  2476
# 27126    10.95     2018-09-11    34507.00         0  Arlington  2474
# 58438    11.39     2016-06-23    37614.00         0  Arlington  2476
# 37392    11.48     2017-11-03    49134.40         0  Arlington  2474
# 57808    11.65     2016-06-30    46000.00         0  Arlington  2474
# 39715    11.72     2017-08-17    36960.00         0  Arlington  2476
# 30478    11.73     2018-06-04    41507.00         0  Arlington  2474
# 39597    11.76     2017-08-23    35510.42         0  Arlington  2474
# 74200    11.92     2015-11-19    41358.34         0  Arlington  2474
# 34803    12.06     2018-01-18    42089.00         0  Arlington  2476
# 34338    12.25     2018-02-02    43520.00         0  Arlington  2476
# 23944    12.54     2018-12-17    44951.00         0  Arlington  2474
# 32915    12.54     2018-03-26    45024.40         0  Arlington  2474
# 60277    12.74     2016-05-25    65611.00         0  Arlington  2474
# 94255    12.75     2014-11-20    62731.00         0  Arlington  2476
# 52589    13.00     2016-09-30    63960.00         0  Arlington  2474
# 60599    13.50     2016-05-20    72221.00         0  Arlington  2474
# 45597    13.50     2017-02-16    56295.00         0  Arlington  2474
# 83136    13.52     2015-07-10    74630.40         0  Arlington  2474
# 63691    13.52     2016-04-06    26155.00         0  Arlington  2474
# 50172    13.76     2016-11-14    58000.00         0  Arlington  2474
# 32928    14.40     2018-03-26    59995.00         0  Arlington  2474
# 58642    17.10     2016-06-21    68229.00         0  Arlington  2476
# 47050    19.80     2017-01-06    57595.00         0  Arlington  2476
# 101929   23.50     2013-12-31        0.01         0  Arlington  2476
# 100639   23.50     2014-04-04        0.01         0  Arlington  2474
# 29415    24.84     2018-07-03    62100.00         0  Arlington  2476
# 103237   36.62     2013-10-08   164808.00         0  Arlington  2476
# 112651   43.89     2009-11-25   303963.00  142003.5  Arlington  2476
# 44293    57.12     2017-03-31   128355.00         0  Arlington  2476
# 73593    70.68     2015-12-01   236000.00         0  Arlington  2476
# 73400    94.24     2015-12-03   290000.00         0  Arlington  2476
# 73316    94.24     2015-12-04   290000.00         0  Arlington  2476
# 113409  105.88     2008-12-18   742368.00  343512.5  Arlington  2474
# 73594   117.80     2015-12-01   350000.00         0  Arlington  2476
# 74199   117.80     2015-11-19   360000.00         0  Arlington  2476
# 73399   223.82     2015-12-03   630000.00         0  Arlington  2476
# 40151   540.00     2017-08-04  1568866.21         0  Arlington  2476
#
#            county                                            program  \
# 68465   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 28984   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 54112   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 52522   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 98735   Middlesex   Commonwealth Solar II;Commonwealth Solar SREC II
# 92348   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 73351   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 27023   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 73370   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 34616   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 27126   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 58438   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 37392   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 57808   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 39715   Middlesex  Commonwealth Solar SREC II;Solar Loan Program;...
# 30478   Middlesex  Commonwealth Solar SREC II;Solar Loan Program;...
# 39597   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 74200   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 34803   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 34338   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 23944   Middlesex  Solar Massachusetts Renewable Target (SMART);N...
# 32915   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 60277   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 94255   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 52589   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 60599   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 45597   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 83136   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 63691   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 50172   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 32928   Middlesex  Commonwealth Solar SREC II;Solar Loan Program;...
# 58642   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 47050   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 101929  Middlesex    Commonwealth Solar SREC I;Non-RET Funded Grants
# 100639  Middlesex    Commonwealth Solar SREC I;Non-RET Funded Grants
# 29415   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 103237  Middlesex    Commonwealth Solar SREC I;Non-RET Funded Grants
# 112651  Middlesex                                 Commonwealth Solar
# 44293   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 73593   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 73400   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 73316   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 113409  Middlesex                                 Commonwealth Solar
# 73594   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 74199   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 73399   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
# 40151   Middlesex   Commonwealth Solar SREC II;Non-RET Funded Grants
#
#                                                      type  \
# 68465   Residential (3 or fewer dwelling units per bui...
# 28984   Residential (3 or fewer dwelling units per bui...
# 54112   Residential (3 or fewer dwelling units per bui...
# 52522   Residential (3 or fewer dwelling units per bui...
# 98735   Residential (3 or fewer dwelling units per bui...
# 92348   Residential (3 or fewer dwelling units per bui...
# 73351   Residential (3 or fewer dwelling units per bui...
# 27023   Residential (3 or fewer dwelling units per bui...
# 73370   Residential (3 or fewer dwelling units per bui...
# 34616   Residential (3 or fewer dwelling units per bui...
# 27126   Residential (3 or fewer dwelling units per bui...
# 58438   Residential (3 or fewer dwelling units per bui...
# 37392   Residential (3 or fewer dwelling units per bui...
# 57808   Residential (3 or fewer dwelling units per bui...
# 39715   Residential (3 or fewer dwelling units per bui...
# 30478   Residential (3 or fewer dwelling units per bui...
# 39597   Residential (3 or fewer dwelling units per bui...
# 74200   Residential (3 or fewer dwelling units per bui...
# 34803   Residential (3 or fewer dwelling units per bui...
# 34338   Residential (3 or fewer dwelling units per bui...
# 23944   Residential (3 or fewer dwelling units per bui...
# 32915   Residential (3 or fewer dwelling units per bui...
# 60277   Residential (3 or fewer dwelling units per bui...
# 94255   Residential (3 or fewer dwelling units per bui...
# 52589   Residential (3 or fewer dwelling units per bui...
# 60599   Residential (3 or fewer dwelling units per bui...
# 45597   Residential (3 or fewer dwelling units per bui...
# 83136   Residential (3 or fewer dwelling units per bui...
# 63691   Residential (3 or fewer dwelling units per bui...
# 50172   Residential (3 or fewer dwelling units per bui...
# 32928   Residential (3 or fewer dwelling units per bui...
# 58642   Residential (3 or fewer dwelling units per bui...
# 47050                                 Commercial / Office
# 101929                                Commercial / Office
# 100639                                Commercial / Office
# 29415                                 Commercial / Office
# 103237                                          Religious
# 112651                                         Industrial
# 44293                                              Retail
# 73593                             Municipal - K-12 School
# 73400                             Municipal - K-12 School
# 73316                             Municipal - K-12 School
# 113409                                Commercial / Office
# 73594                             Municipal - K-12 School
# 74199                             Municipal - K-12 School
# 73399                             Municipal - K-12 School
# 40151                                          Industrial
#
#                                                 installer  \
# 68465                          SolarCity DBA Tesla Energy
# 28984                                     Great Sky Solar
# 54112                             SolarFlair Energy, Inc.
# 52522                          SolarCity DBA Tesla Energy
# 98735   New England Clean Energy (formerly New England...
# 92348                          SolarCity DBA Tesla Energy
# 73351                                Boston Solar Company
# 27023                                         Sunrun Inc.
# 73370                                           RevoluSun
# 34616                          Sunlight Solar Energy Inc.
# 27126                                     Great Sky Solar
# 58438                                 Direct Energy Solar
# 37392                                        Vivint Solar
# 57808                                     621 Energy, LLC
# 39715                             United Solar Associates
# 30478                                          Solar Five
# 39597                                       Trinity Solar
# 74200                                       Trinity Solar
# 34803                                        SunBug Solar
# 34338                          Sunlight Solar Energy Inc.
# 23944   New England Clean Energy (formerly New England...
# 32915                                           RevoluSun
# 60277                          SolarCity DBA Tesla Energy
# 94255                                        SunBug Solar
# 52589                          SolarCity DBA Tesla Energy
# 60599                            Blue Selenium Solar, LLC
# 45597                                        Vivint Solar
# 83136                          SolarCity DBA Tesla Energy
# 63691                                         Sunrun Inc.
# 50172                                       AC Solar, LLC
# 32928                            Blue Selenium Solar, LLC
# 58642                                Transformations, Inc
# 47050                                       Arcadia Power
# 101929                     Solect Energy Development, LLC
# 100639                     Solect Energy Development, LLC
# 29415                   Invaleon Technologies Corporation
# 103237                                       SunBug Solar
# 112651                                        Nexamp, Inc
# 44293                                    Microgrid Energy
# 73593                                      Ameresco, Inc.
# 73400                                      Ameresco, Inc.
# 73316                                      Ameresco, Inc.
# 113409                                        Nexamp, Inc
# 73594                                      Ameresco, Inc.
# 74199                                      Ameresco, Inc.
# 73399                                      Ameresco, Inc.
# 40151                      Solect Energy Development, LLC
#
#                                               module_mfgr  \
# 68465   REC Solar;SolarEdge Technologies;Continental C...
# 28984        LG Electronics;Enphase Energy;Enphase Energy
# 54112               Canadian Solar;Enphase Energy;Milbank
# 52522                             Trina Solar;Delta;Delta
# 98735                              SunPower;Power-One;TBD
# 92348   Canadian Solar;SolarEdge Technologies;SolarEdg...
# 73351                      SunPower;SunPower;Locus Energy
# 27023   LG Electronics;SolarEdge Technologies;Continen...
# 73370        SunPower;SolarEdge Technologies;Locus Energy
# 34616        LG Electronics;Enphase Energy;Enphase Energy
# 27126        LG Electronics;Enphase Energy;Enphase Energy
# 58438         Hanwha SolarOne;Enphase Energy;Locus Energy
# 37392   Jinko Solar;SolarEdge Technologies;Continental...
# 57808   LG Electronics;SolarEdge Technologies;Continen...
# 39715   LG Electronics;SolarEdge Technologies;Continen...
# 30478   LG Electronics;SolarEdge Technologies;Continen...
# 39597            Jinko Solar;SolarEdge Technologies;Itron
# 74200        Hanwha SolarOne;SolarEdge Technologies;Itron
# 34803   LG Electronics;SolarEdge Technologies;Continen...
# 34338        LG Electronics;Enphase Energy;Enphase Energy
# 23944   Sanyo Electric of Panasonic Group;SolarEdge Te...
# 32915   Sanyo Electric of Panasonic Group;SolarEdge Te...
# 60277   Trina Solar;SolarEdge Technologies;Elkor Techn...
# 94255        SunPower;SolarEdge Technologies;Locus Energy
# 52589   Trina Solar;SolarEdge Technologies;Continental...
# 60599                  SunPower;SunPower;General Electric
# 45597   JA Solar;SolarEdge Technologies;Continental Co...
# 83136   Trina Solar;SolarEdge Technologies;Continental...
# 63691      Canadian Solar;Enphase Energy;General Electric
# 50172   LG Electronics;SolarEdge Technologies;Continen...
# 32928                  SunPower;SunPower;General Electric
# 58642   LG Electronics;SolarEdge Technologies;SolarEdg...
# 47050   Silfab;SolarEdge Technologies;Continental Cont...
# 101929   ET Solar;SolarEdge Technologies;General Electric
# 100639   ET Solar;SolarEdge Technologies;General Electric
# 29415   Trina Solar;SolarEdge Technologies;SolarEdge T...
# 103237                              SunPower;SunPower;TBD
# 112651          Kyocera Solar;Yaskawa Solectria Solar;TBD
# 44293      LG Electronics;Enphase Energy;Veris Industries
# 73593   Hyundai Heavy Industries;Yaskawa Solectria Sol...
# 73400   Hyundai Heavy Industries;Yaskawa Solectria Sol...
# 73316   Hyundai Heavy Industries;Yaskawa Solectria Sol...
# 113409  Solarfun Power;Yaskawa Solectria Solar;Solectr...
# 73594   Hyundai Heavy Industries;Yaskawa Solectria Sol...
# 74199   Hyundai Heavy Industries;Yaskawa Solectria Sol...
# 73399   Hyundai Heavy Industries;Yaskawa Solectria Sol...
# 40151   LG Electronics;Yaskawa Solectria Solar;Veris I...
#
#                                           inverter_mfgr  \
# 68465                            SolarEdge Technologies
# 28984                                    Enphase Energy
# 54112                                    Enphase Energy
# 52522                                             Delta
# 98735                                         Power-One
# 92348     SolarEdge Technologies;SolarEdge Technologies
# 73351                                          SunPower
# 27023                            SolarEdge Technologies
# 73370                            SolarEdge Technologies
# 34616                                    Enphase Energy
# 27126                                    Enphase Energy
# 58438                                    Enphase Energy
# 37392                            SolarEdge Technologies
# 57808                            SolarEdge Technologies
# 39715                            SolarEdge Technologies
# 30478                            SolarEdge Technologies
# 39597                            SolarEdge Technologies
# 74200                            SolarEdge Technologies
# 34803                            SolarEdge Technologies
# 34338                                    Enphase Energy
# 23944                            SolarEdge Technologies
# 32915                            SolarEdge Technologies
# 60277                            SolarEdge Technologies
# 94255                            SolarEdge Technologies
# 52589                            SolarEdge Technologies
# 60599                                          SunPower
# 45597                            SolarEdge Technologies
# 83136                            SolarEdge Technologies
# 63691                                    Enphase Energy
# 50172                            SolarEdge Technologies
# 32928                                          SunPower
# 58642     SolarEdge Technologies;SolarEdge Technologies
# 47050                            SolarEdge Technologies
# 101929                           SolarEdge Technologies
# 100639                           SolarEdge Technologies
# 29415     SolarEdge Technologies;SolarEdge Technologies
# 103237                                         SunPower
# 112651                          Yaskawa Solectria Solar
# 44293                                    Enphase Energy
# 73593                           Yaskawa Solectria Solar
# 73400   Yaskawa Solectria Solar;Yaskawa Solectria Solar
# 73316   Yaskawa Solectria Solar;Yaskawa Solectria Solar
# 113409                          Yaskawa Solectria Solar
# 73594   Yaskawa Solectria Solar;Yaskawa Solectria Solar
# 74199   Yaskawa Solectria Solar;Yaskawa Solectria Solar
# 73399   Yaskawa Solectria Solar;Yaskawa Solectria Solar
# 40151                           Yaskawa Solectria Solar
#
#                                                meter_mfgr  \
# 68465   Continental Control Systems /WattNode (SolarEdge)
# 28984                                      Enphase Energy
# 54112                                             Milbank
# 52522                                               Delta
# 98735                                                 TBD
# 92348   Continental Control Systems /WattNode (SolarEdge)
# 73351                                        Locus Energy
# 27023   Continental Control Systems /WattNode (SolarEdge)
# 73370                                        Locus Energy
# 34616                                      Enphase Energy
# 27126                                      Enphase Energy
# 58438                                        Locus Energy
# 37392   Continental Control Systems /WattNode (SolarEdge)
# 57808   Continental Control Systems /WattNode (SolarEdge)
# 39715   Continental Control Systems /WattNode (SolarEdge)
# 30478   Continental Control Systems /WattNode (SolarEdge)
# 39597                                               Itron
# 74200                                               Itron
# 34803   Continental Control Systems /WattNode (SolarEdge)
# 34338                                      Enphase Energy
# 23944                                         SMART Meter
# 32915   Continental Control Systems /WattNode (SolarEdge)
# 60277                                  Elkor Technologies
# 94255                                        Locus Energy
# 52589   Continental Control Systems /WattNode (SolarEdge)
# 60599                                    General Electric
# 45597   Continental Control Systems /WattNode (SolarEdge)
# 83136   Continental Control Systems /WattNode (SolarEdge)
# 63691                                    General Electric
# 50172   Continental Control Systems /WattNode (SolarEdge)
# 32928                                    General Electric
# 58642                                    General Electric
# 47050   Continental Control Systems /WattNode (SolarEdge)
# 101929                                   General Electric
# 100639                                   General Electric
# 29415   Continental Control Systems /WattNode (SolarEdge)
# 103237                                                TBD
# 112651                                                TBD
# 44293                                    Veris Industries
# 73593                                  Elkor Technologies
# 73400                                  Elkor Technologies
# 73316                                  Elkor Technologies
# 113409                               Solectria Renewables
# 73594                                  Elkor Technologies
# 74199                                  Elkor Technologies
# 73399                                  Elkor Technologies
# 40151                                    Veris Industries
#
#                        utility owner srec  est_annual_kWh       perWatt  \
# 68465   NSTAR (DBA EverSource)     Y    Y      12387.0000  5.600000e+00
# 28984   NSTAR (DBA EverSource)     N    Y      11163.0000  3.000000e+00
# 54112   NSTAR (DBA EverSource)     N    Y      14073.0000  3.671064e+00
# 52522   NSTAR (DBA EverSource)     Y    Y      10870.0000  4.920000e+00
# 98735   NSTAR (DBA EverSource)     N    Y      13734.0000  5.328489e+00
# 92348   NSTAR (DBA EverSource)     Y    Y      12601.0000  5.497371e+00
# 73351   NSTAR (DBA EverSource)     N    Y      12600.0000  4.685619e+00
# 27023   NSTAR (DBA EverSource)     Y    Y       9011.0000  1.919223e+00
# 73370   NSTAR (DBA EverSource)     N    Y      11158.0000  4.492882e+00
# 34616   NSTAR (DBA EverSource)     N    Y      13086.0000  3.500000e+00
# 27126   NSTAR (DBA EverSource)     N    Y      13024.0000  3.151324e+00
# 58438   NSTAR (DBA EverSource)     N    Y      14603.0000  3.302371e+00
# 37392   NSTAR (DBA EverSource)     Y    Y      10230.0000  4.280000e+00
# 57808   NSTAR (DBA EverSource)     N    Y      15200.0000  3.948498e+00
# 39715   NSTAR (DBA EverSource)     N    Y      13551.0000  3.153584e+00
# 30478   NSTAR (DBA EverSource)     N    Y      13027.0000  3.538534e+00
# 39597   NSTAR (DBA EverSource)     Y    Y      12184.0000  3.019594e+00
# 74200   NSTAR (DBA EverSource)     Y    Y      12840.0000  3.469659e+00
# 34803   NSTAR (DBA EverSource)     N    Y      14575.0000  3.489967e+00
# 34338   NSTAR (DBA EverSource)     N    Y      17528.0000  3.552653e+00
# 23944   NSTAR (DBA EverSource)     N    N      14543.8406  3.584609e+00
# 32915   NSTAR (DBA EverSource)     N    Y      14084.0000  3.590463e+00
# 60277   NSTAR (DBA EverSource)     Y    Y      11730.0000  5.150000e+00
# 94255   NSTAR (DBA EverSource)     N    Y      14337.0000  4.920078e+00
# 52589   NSTAR (DBA EverSource)     Y    Y      13840.0000  4.920000e+00
# 60599   NSTAR (DBA EverSource)     N    Y      17969.0000  5.349704e+00
# 45597   NSTAR (DBA EverSource)     Y    Y      10536.0000  4.170000e+00
# 83136   NSTAR (DBA EverSource)     Y    Y      15475.0000  5.520000e+00
# 63691   NSTAR (DBA EverSource)     Y    Y      11552.0000  1.934541e+00
# 50172   NSTAR (DBA EverSource)     N    Y      16512.0000  4.215116e+00
# 32928   NSTAR (DBA EverSource)     N    Y      18157.0000  4.166319e+00
# 58642   NSTAR (DBA EverSource)     N    Y      19267.0000  3.990000e+00
# 47050   NSTAR (DBA EverSource)     N    Y      24156.0000  2.908838e+00
# 101929  NSTAR (DBA EverSource)     N    Y      26320.0000  4.255319e-07
# 100639  NSTAR (DBA EverSource)     N    Y      25500.0000  4.255319e-07
# 29415   NSTAR (DBA EverSource)     Y    Y      29808.0000  2.500000e+00
# 103237  NSTAR (DBA EverSource)     N    Y      50218.0000  4.500492e+00
# 112651  NSTAR (DBA EverSource)     N    N      44375.0000  6.925564e+00
# 44293   NSTAR (DBA EverSource)     Y    Y      65112.0000  2.247111e+00
# 73593   NSTAR (DBA EverSource)     Y    Y      83409.0000  3.338993e+00
# 73400   NSTAR (DBA EverSource)     Y    Y     117482.0000  3.077250e+00
# 73316   NSTAR (DBA EverSource)     Y    Y     112364.0000  3.077250e+00
# 113409  NSTAR (DBA EverSource)     N    N     117765.0000  7.011409e+00
# 73594   NSTAR (DBA EverSource)     Y    Y     140482.0000  2.971138e+00
# 74199   NSTAR (DBA EverSource)     Y    Y     138649.0000  3.056027e+00
# 73399   NSTAR (DBA EverSource)     Y    Y     267882.0000  2.814762e+00
# 40151   NSTAR (DBA EverSource)     N    Y     639000.0000  2.905308e+00
#
#        install_yr
# 68465        2016
# 28984        2018
# 54112        2016
# 52522        2016
# 98735        2014
# 92348        2015
# 73351        2015
# 27023        2018
# 73370        2015
# 34616        2018
# 27126        2018
# 58438        2016
# 37392        2017
# 57808        2016
# 39715        2017
# 30478        2018
# 39597        2017
# 74200        2015
# 34803        2018
# 34338        2018
# 23944        2018
# 32915        2018
# 60277        2016
# 94255        2014
# 52589        2016
# 60599        2016
# 45597        2017
# 83136        2015
# 63691        2016
# 50172        2016
# 32928        2018
# 58642        2016
# 47050        2017
# 101929       2013
# 100639       2014
# 29415        2018
# 103237       2013
# 112651       2009
# 44293        2017
# 73593        2015
# 73400        2015
# 73316        2015
# 113409       2008
# 73594        2015
# 74199        2015
# 73399        2015
# 40151        2017

# %%
PERCENT_OF_ALL_INSTALLS = 0.85
pts['perWatt'] = pts . cost . div ( pts . kW ) / 1000

mask = (pts['type'].str.contains('Residential')) &\
                                (pts['effective_date']>='2020-01-01') &\
                                (pts['effective_date']<='2021-12-31') &\
                                (pts['cost']>0)   &\
                                (pts['perWatt']<10)  ##note 150 installs have no cost## 432 installs with outlier costs



installers = pts[mask].groupby('installer').agg({
    "kW":[sum,np.median],
    "effective_date":len,
    "perWatt":[np.median,min,max]
})#.sort_values('date',ascending=False)
installers.columns = ['kW_total','kW_median','systems','costPerWatt_median','costPerWatt_min','costPerWatt_max']

for col in ['costPerWatt_median','costPerWatt_min','costPerWatt_max'] :
    installers[col] = installers[col].apply(locale.currency)
    
installers=installers.sort_values('systems',ascending=False)

mask = installers['systems'].cumsum() <= PERCENT_OF_ALL_INSTALLS*len(pts[mask])
print(installers[mask].to_markdown())
# Out:
# | installer                                 |   kW_total |   kW_median |   systems | costPerWatt_median   | costPerWatt_min   | costPerWatt_max   |
# |:------------------------------------------|-----------:|------------:|----------:|:---------------------|:------------------|:------------------|
# | Vivint Solar                              |   28758.1  |       7.8   |      3458 | $3.46                | $1.63             | $7.24             |
# | Trinity Solar                             |   17474.2  |       6.93  |      2315 | $4.02                | $2.16             | $8.38             |
# | Sunrun Inc.                               |    8588.69 |       8.23  |      1046 | $2.99                | $1.49             | $6.72             |
# | Boston Solar Company                      |    3945.81 |      10.08  |       392 | $3.44                | $1.79             | $8.43             |
# | SolarCity DBA Tesla Energy                |    3184.85 |       8.16  |       364 | $2.85                | $1.84             | $7.26             |
# | Palmetto Solar                            |    2609.77 |       7.44  |       327 | $4.26                | $2.20             | $8.35             |
# | Freedom Forever Massachusetts, LLC        |    1827.84 |       8.09  |       224 | $3.71                | $2.71             | $7.01             |
# | Bright Planet Solar                       |    1818.91 |       8.68  |       208 | $4.08                | $1.08             | $7.23             |
# | Devlin Contracting                        |    1741.18 |       8     |       205 | $4.11                | $1.89             | $7.61             |
# | SunBug Solar                              |    1933.53 |      10.05  |       191 | $3.52                | $2.48             | $6.97             |
# | Northeast Solar Services DBA Revolusun    |    1733.13 |       9.37  |       174 | $3.61                | $2.93             | $7.45             |
# | Isaksen Solar                             |    1617.92 |       9.995 |       156 | $3.75                | $2.15             | $6.09             |
# | My Generation Energy                      |    1123.27 |       7.385 |       140 | $3.38                | $2.34             | $7.97             |
# | Northeast Solar                           |    1133.42 |       8.71  |       130 | $3.14                | $2.29             | $8.08             |
# | Great Sky Solar                           |    1204.8  |       9.47  |       126 | $2.93                | $2.05             | $5.19             |
# | Summit Energy Group                       |    1099.86 |       8.36  |       124 | $4.22                | $2.34             | $7.39             |
# | SunPower Corporation                      |    1060.46 |       7.47  |       124 | $4.22                | $2.05             | $5.99             |
# | SolarFlair Energy, Inc.                   |     875.27 |       6.48  |       119 | $3.00                | $2.23             | $7.77             |
# | All Energy Solar                          |     957.44 |       9.38  |        98 | $3.14                | $2.17             | $7.51             |
# | ReVision Energy                           |     973.43 |       9.395 |        98 | $3.69                | $2.67             | $9.92             |
# | Valley Solar                              |     926.62 |      10.5   |        91 | $3.29                | $2.39             | $6.62             |
# | PV Squared (Pioneer Valley Photovoltaics) |     893.08 |       9.47  |        90 | $3.61                | $2.75             | $6.91             |

# %%
mask = (pts['type'].str.contains('Residential')) &\
                                (pts['effective_date']>='2020-01-01') &\
                                (pts['effective_date']<='2021-12-31')&\
                                (pts['county']=='Middlesex')&\
                                (pts['city']=='Arlington')
installers = pts[mask].groupby('installer').agg({
    "kW":[sum,np.median],
    "effective_date":len,
    "perWatt" : np.median
}).sort_values(("effective_date","len"),ascending=False)
installers.columns = ['total kW installed','median size (kW)','installs','cost_per_Watt']
installers['cost_per_Watt'] = installers['cost_per_Watt'].apply(locale.currency)
installers
# Out:
#                                         total kW installed  median size (kW)  \
# installer
# Trinity Solar                                        89.04             5.830
# SunBug Solar                                        105.13             7.400
# Great Sky Solar                                      75.55             8.760
# Boston Solar Company                                 61.34             6.550
# Vivint Solar                                         47.38             4.550
# Sunrun Inc.                                          28.33             4.950
# SolarCity DBA Tesla Energy                           34.62             7.860
# SolarFlair Energy, Inc.                              24.06             5.025
# NuWatt Energy LLC                                    11.05             3.580
# ReVision Energy                                      22.47             7.400
# BrightStar Solar                                     17.81             8.905
# Energy Monster                                       11.10             5.550
# Northeast Solar Services DBA Revolusun               18.87             9.435
# Sunlight Solar Energy Inc.                            8.88             8.880
# SunRay Solar, LLC                                     2.96             2.960
# Summit Energy Group                                   3.20             3.200
# ACE Residential Solar LLC                             7.00             7.000
# Skyline Solar LLC                                    11.05            11.050
# Second Generation Energy                             13.50            13.500
# Apex Solar                                            4.96             4.960
# New Day Energy                                        6.20             6.200
# Invaleon Technologies Corporation                    11.20            11.200
# Devlin Contracting                                    5.76             5.760
# Cazeault Solar                                        3.20             3.200
# Brightway Energy LLC                                  8.75             8.750
# PLUGPV                                                9.62             9.620
#
#                                         installs cost_per_Watt
# installer
# Trinity Solar                                 14         $4.20
# SunBug Solar                                  13         $3.88
# Great Sky Solar                                9         $3.02
# Boston Solar Company                           8         $4.42
# Vivint Solar                                   7         $3.46
# Sunrun Inc.                                    5         $3.53
# SolarCity DBA Tesla Energy                     4         $3.70
# SolarFlair Energy, Inc.                        4         $3.30
# NuWatt Energy LLC                              3         $3.85
# ReVision Energy                                3         $3.28
# BrightStar Solar                               2         $3.44
# Energy Monster                                 2         $3.04
# Northeast Solar Services DBA Revolusun         2         $4.57
# Sunlight Solar Energy Inc.                     1         $3.61
# SunRay Solar, LLC                              1         $4.90
# Summit Energy Group                            1         $7.39
# ACE Residential Solar LLC                      1         $3.20
# Skyline Solar LLC                              1         $5.13
# Second Generation Energy                       1         $2.95
# Apex Solar                                     1         $2.98
# New Day Energy                                 1         $4.08
# Invaleon Technologies Corporation              1         $2.88
# Devlin Contracting                             1         $3.83
# Cazeault Solar                                 1         $3.90
# Brightway Energy LLC                           1         $3.60
# PLUGPV                                         1         $4.25

# %%
pts [ 'install_yr' ] = pts [ 'effective_date' ] . dt . strftime( '%Y' )

mask = pts [ 'type' ] . str . contains ( 'Residential|residential' )

evolution = pts [ mask ] . groupby ( 'install_yr' ) . agg (
    {
        "kW" : [ sum , np . median , min , max ] ,
        "install_yr" : len ,
        "perWatt" : [ np . median , min , max ] ,
        "est_annual_kWh" : sum
    }
)

evolution . columns = ['kW_sum'         ,
                       'kW_median'      ,
                       'kW_min'         ,
                       'kW_max'         ,
                       'installs'       ,
                       'perWatt_median' ,
                       'perWatt_min'    ,
                       'perWatt_max'    ,
                       'est_annual_kWh'
                      ]


# %matplotlib widget

fig, ( ax1 ) = plt . subplots ( ncols = 1 )


x = np . array ( evolution [ 'est_annual_kWh' ] )

ax1 . plot ( 
    evolution [ 'est_annual_kWh' ] . cumsum ( ) / 1e6 , 
    label = 'Cumulative Energy Generated' , 
    lw = 3
)
ax1 . set_title  ( 'MA Residential Solar PV Systems\nAdded Capacity' )
ax1 . set_xlabel ( 'Year Installed' , fontsize = 12 )
ax1 . set_ylabel ( 'Annual GWh Generated (est.)' , fontsize = 12 )

ax = ( evolution [ 'kW_sum' ] / 1000 ) . plot . bar ( 
    secondary_y = True , 
    color = 'g' , 
    label = 'New Power Capacity' ,
    rot = 45
)

ax . set_ylabel ( 'MW', fontsize = 12 )
ax . set_xlabel ( 'Year Installed', fontsize = 12 )

h1, l1 = ax1 . get_legend_handles_labels ( )
h2, l2 = ax  . get_legend_handles_labels ( )


plt . legend ( h1 + h2 , l1 + l2, loc = 'center left' )
plt . show ( )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget

fig, ( ax1 ) = plt . subplots ( ncols = 1 )

##note 150 installs have no cost## 432 installs with outlier costs

mask = ( pts [ 'type' ] . str . contains ( 'Residential' ) ) &\
       ( pts [ 'effective_date' ] >= '2018-01-01' )           &\
       ( pts [ 'effective_date' ] <= '2021-12-31' )            &\
       ( pts [ 'cost' ] > 0 )                                   &\
       ( pts [ 'perWatt' ] < 10 ) 


x = np . array ( pts [ mask ] [ 'perWatt' ] )
# filtered = x [ ~is_outlier ( x , 3 ) ]

ax1 . hist ( x , bins = 30 )
ax1 . set_title  ( 'Residential Solar PV Systems\nCost Per Watt Installed\nSince 2018' )
ax1 . set_xlabel ( '' )
ax1 . set_ylabel ( 'Systems' )

fmt   =  '${x:,.2f}'
tick  =  mtick . StrMethodFormatter ( fmt )
ax1 . xaxis . set_major_formatter ( tick )

textstr = '\n'.join((
    r'$\mathrm{average}=\$%.2f$' %(x.mean(),),
    r'$\mathrm{median}=\$%.2f$' %(np.median(x),),
    r'$\sigma=\$%.2f$' %(x.std(),)
))

props = dict(boxstyle='round', facecolor='wheat', alpha = 0.5)
ax1.text(.485, .85, textstr, transform=ax1.transAxes, fontsize=14, verticalalignment='top', bbox = props)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Commercial Renewable Assets, out of state PVs
#
# * aps, rps2 and class2 are all commercial(-like) generators
#
# * aps =  mostly cogeneration CHP facilities at universities/hospitals, some fuel cells, flywheels and waste incinerators
# * class2 = mostly out-of-state hydroelectric, some landfill gas, coupla wind
# * rps0 = mostly out-of-state PV, PV farms and wind.  some other
# * waste = municipal trash incinerators

# %%
def combine_commercial ( docs ) :

    all_df = pd . DataFrame ( )

    for program in ['aps' , 'rps1' , 'class2' , 'waste' ] :

    #     df = docs [ program ] . groupby ( [ 'state' , 'fuel' ] ) . agg ( { "MW" : [ len , sum ] } ) . reset_index ( )
        df = docs [ program ] . groupby ( [ 'fuel' ] ) . agg ( { "MW" : [ len , sum ] } ) . reset_index ( )
        df . columns = [ 'fuel' , 'systems' , 'MW']
        df [ 'program' ] = program
        all_df = all_df . append ( df )

    return all_df . sort_values ( [ 'MW' ] , ascending = False ) . reset_index ( drop = True )

commercial = combine_commercial ( docs )

# %%
commercial
# Out:
#                           fuel  systems           MW program
# 0                         Wind      133  4349.925300    rps1
# 1                 Photovoltaic     8971  1649.693935    rps1
# 2              Natural Gas/CHP       96   499.888000     aps
# 3                Hydroelectric       57   436.306700    rps1
# 4                Hydroelectric      150   367.678700  class2
# 5              Waste to Energy        7   283.545000   waste
# 6                 Landfill Gas       62   258.783000    rps1
# 7           Anaerobic Digester       30    55.875000    rps1
# 8                 Landfill Gas        8    20.165000  class2
# 9       Natural Gas/Fuel Cell        19     8.653863     aps
# 10                        Wind        2     6.010000  class2
# 11            Flywheel Storage        2     3.000000     aps
# 12  Natural & Digester Gas/CHP        2     2.300000     aps
# 13                     Biomass        6     1.935000    rps1
# 14                       Tidal        1     0.900000    rps1
# 15     Waste-to-Thermal Energy        2     0.861000     aps
# 16           Woody Biomass/CHP        2     0.709000     aps
# 17            Digester Gas/CHP        2     0.420000     aps
# 18                Photovoltaic        1     0.100000  class2
# 19                Hydrokinetic        1     0.085000  class2
# 20                Hydrokinetic        1     0.085000    rps1

# %%
mask = docs['rps1'].fuel=='Photovoltaic'
#mask = docs['rps1'].fuel=='Wind'
foo=docs['rps1'][mask]
foo = foo[['state','type']].groupby('state').count().sort_values('type',ascending=False).reset_index()
foo.columns = ['state','PV systems in RPS 1']
foo
# Out:
#   state  PV systems in RPS 1
# 0    NH                 4415
# 1    CT                 2441
# 2    ME                  676
# 3    VT                  528
# 4    MA                  494
# 5    RI                  410
# 6    NY                    7
